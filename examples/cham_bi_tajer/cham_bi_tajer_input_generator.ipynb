# %%
from coregiver import input_maker
import os # Needed for checking file existence and content
import numpy as np
import pandas as pd

# %%
# Uniform
n_cham_bench = 154
m_emb = 2.8e-7 * np.ones(14) #solMass
m_pl = 2.8e-8 * np.ones(140) #solMass
m_cham_bench = np.concatenate((m_emb, m_pl))
cmf_uni = 0.33
output_file_example = "uniform_33.txt"

# 3. Call the function to generate the file
input_maker.generate_input_uniform(n_cham_bench, m_cham_bench, cmf_uni, output_file_example)

# 4. (Optional) Verify the file was created and inspect its content
print(f"\nChecking if '{output_file_example}' exists...")
if os.path.exists(output_file_example):
    print(f"File '{output_file_example}' found!")
    print("\nFirst 5 lines of the generated file:")
    with open(output_file_example, 'r') as f:
        for _ in range(6): # Read header + 5 data lines
            line = f.readline()
            if not line:
                break
            print(line.strip())
else:
    print(f"File '{output_file_example}' was NOT found.")
# Out:
# Generating 154 particles with CMF=0.33...
# Output file: uniform_33.txt
# Successfully generated 'uniform_33.txt' with 154 entries.
#
# Checking if 'uniform_33.txt' exists...
# File 'uniform_33.txt' found!
#
# First 5 lines of the generated file:
# 1	2.80000000e-07	3.30000000e-01
# 2	2.80000000e-07	3.30000000e-01
# 3	2.80000000e-07	3.30000000e-01
# 4	2.80000000e-07	3.30000000e-01
# 5	2.80000000e-07	3.30000000e-01
# 6	2.80000000e-07	3.30000000e-01

# %%
# Uniform, Higher metallicity
n_cham_bench = 154
m_emb = 2.8e-7 * np.ones(14) #solMass
m_pl = 2.8e-8 * np.ones(140) #solMass
m_cham_bench = np.concatenate((m_emb, m_pl))
cmf_uni = 0.4
output_file_example = "uniform_40.txt"

# 3. Call the function to generate the file
input_maker.generate_input_uniform(n_cham_bench, m_cham_bench, cmf_uni, output_file_example)

# 4. (Optional) Verify the file was created and inspect its content
print(f"\nChecking if '{output_file_example}' exists...")
if os.path.exists(output_file_example):
    print(f"File '{output_file_example}' found!")
    print("\nFirst 5 lines of the generated file:")
    with open(output_file_example, 'r') as f:
        for _ in range(6): # Read header + 5 data lines
            line = f.readline()
            if not line:
                break
            print(line.strip())
else:
    print(f"File '{output_file_example}' was NOT found.")
# Out:
# Generating 154 particles with CMF=0.4...
# Output file: uniform_40.txt
# Successfully generated 'uniform_40.txt' with 154 entries.
#
# Checking if 'uniform_40.txt' exists...
# File 'uniform_40.txt' found!
#
# First 5 lines of the generated file:
# 1	2.80000000e-07	4.00000000e-01
# 2	2.80000000e-07	4.00000000e-01
# 3	2.80000000e-07	4.00000000e-01
# 4	2.80000000e-07	4.00000000e-01
# 5	2.80000000e-07	4.00000000e-01
# 6	2.80000000e-07	4.00000000e-01

# %% [markdown]
# # Step-function input example

# %%
#Ueda V3 example

percentages = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45]
bounds = [0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8]
base_cmf = 0.33
semis_emb = np.loadtxt('cham_bimodal_emb_samples_sep3.txt')
semis_pl = np.loadtxt('cham_bimodal_pl_samples_sep3.txt')
semis_cham_bench = np.concatenate((semis_emb, semis_pl))

cmf_grid = pd.DataFrame(columns=['bounds', 'percentages', 'inner_cmf', 'outer_cmf'])
grid_index = 0

for bound in bounds:
    for perc in percentages:
        cmf1, cmf2 = input_maker.get_dual_cmf(m_cham_bench, [0], semis_cham_bench, [0], bound, perc, base_cmf)

        # Skip if any CMF > 1
        if cmf1 > 1 or cmf2 > 1:
            print(f"⚠️ Skipping: Bound = {bound}, perc. = {perc} → CMF > 1 (CMF_in = {cmf1:.4}, CMF_out = {cmf2:.4})")
            continue

        input_maker.generate_input_step_function(
            n_cham_bench, m_cham_bench, semis_cham_bench, cmf1, cmf2, bound,
            f"step_functions/cham_bi_tajer_step_b{bound}_p{perc}.txt"
        )

        cmf_grid.loc[grid_index] = {
            'bounds': bound,
            'percentages': perc,
            'inner_cmf': cmf1,
            'outer_cmf': cmf2
        }

        print(f"Bound = {bound}, perc. of Fe trans. = {perc}, CMF_in = {cmf1:.4}, CMF_out = {cmf2:.4}")
        grid_index += 1
# Out:
# ⚠️ Skipping: Bound = 0.5, perc. = 0.05 → CMF > 1 (CMF_in = 1.469, CMF_out = 0.3135)
# ⚠️ Skipping: Bound = 0.5, perc. = 0.1 → CMF > 1 (CMF_in = 2.607, CMF_out = 0.297)
# ⚠️ Skipping: Bound = 0.5, perc. = 0.15 → CMF > 1 (CMF_in = 3.746, CMF_out = 0.2805)
# ⚠️ Skipping: Bound = 0.5, perc. = 0.2 → CMF > 1 (CMF_in = 4.884, CMF_out = 0.264)
# ⚠️ Skipping: Bound = 0.5, perc. = 0.25 → CMF > 1 (CMF_in = 6.023, CMF_out = 0.2475)
# ⚠️ Skipping: Bound = 0.5, perc. = 0.3 → CMF > 1 (CMF_in = 7.161, CMF_out = 0.231)
# ⚠️ Skipping: Bound = 0.5, perc. = 0.35 → CMF > 1 (CMF_in = 8.3, CMF_out = 0.2145)
# ⚠️ Skipping: Bound = 0.5, perc. = 0.4 → CMF > 1 (CMF_in = 9.438, CMF_out = 0.198)
# ⚠️ Skipping: Bound = 0.5, perc. = 0.45 → CMF > 1 (CMF_in = 10.58, CMF_out = 0.1815)
# ⚠️ Skipping: Bound = 0.55, perc. = 0.05 → CMF > 1 (CMF_in = 1.084, CMF_out = 0.3135)
# ⚠️ Skipping: Bound = 0.55, perc. = 0.1 → CMF > 1 (CMF_in = 1.837, CMF_out = 0.297)
# ⚠️ Skipping: Bound = 0.55, perc. = 0.15 → CMF > 1 (CMF_in = 2.591, CMF_out = 0.2805)
# ⚠️ Skipping: Bound = 0.55, perc. = 0.2 → CMF > 1 (CMF_in = 3.344, CMF_out = 0.264)
# ⚠️ Skipping: Bound = 0.55, perc. = 0.25 → CMF > 1 (CMF_in = 4.098, CMF_out = 0.2475)
# ⚠️ Skipping: Bound = 0.55, perc. = 0.3 → CMF > 1 (CMF_in = 4.851, CMF_out = 0.231)
# ⚠️ Skipping: Bound = 0.55, perc. = 0.35 → CMF > 1 (CMF_in = 5.605, CMF_out = 0.2145)
# ⚠️ Skipping: Bound = 0.55, perc. = 0.4 → CMF > 1 (CMF_in = 6.358, CMF_out = 0.198)
# ⚠️ Skipping: Bound = 0.55, perc. = 0.45 → CMF > 1 (CMF_in = 7.112, CMF_out = 0.1815)
# Output file: step_functions/cham_bi_tajer_step_b0.6_p0.05.txt
# Successfully generated 'step_functions/cham_bi_tajer_step_b0.6_p0.05.txt' with 154 entries.
# Bound = 0.6, perc. of Fe trans. = 0.05, CMF_in = 0.7335, CMF_out = 0.3135
# ⚠️ Skipping: Bound = 0.6, perc. = 0.1 → CMF > 1 (CMF_in = 1.137, CMF_out = 0.297)
# ⚠️ Skipping: Bound = 0.6, perc. = 0.15 → CMF > 1 (CMF_in = 1.541, CMF_out = 0.2805)
# ⚠️ Skipping: Bound = 0.6, perc. = 0.2 → CMF > 1 (CMF_in = 1.944, CMF_out = 0.264)
# ⚠️ Skipping: Bound = 0.6, perc. = 0.25 → CMF > 1 (CMF_in = 2.348, CMF_out = 0.2475)
# ⚠️ Skipping: Bound = 0.6, perc. = 0.3 → CMF > 1 (CMF_in = 2.751, CMF_out = 0.231)
# ⚠️ Skipping: Bound = 0.6, perc. = 0.35 → CMF > 1 (CMF_in = 3.155, CMF_out = 0.2145)
# ⚠️ Skipping: Bound = 0.6, perc. = 0.4 → CMF > 1 (CMF_in = 3.558, CMF_out = 0.198)
# ⚠️ Skipping: Bound = 0.6, perc. = 0.45 → CMF > 1 (CMF_in = 3.962, CMF_out = 0.1815)
# Output file: step_functions/cham_bi_tajer_step_b0.65_p0.05.txt
# Successfully generated 'step_functions/cham_bi_tajer_step_b0.65_p0.05.txt' with 154 entries.
# Bound = 0.65, perc. of Fe trans. = 0.05, CMF_in = 0.6023, CMF_out = 0.3135
# Output file: step_functions/cham_bi_tajer_step_b0.65_p0.1.txt
# Successfully generated 'step_functions/cham_bi_tajer_step_b0.65_p0.1.txt' with 154 entries.
# Bound = 0.65, perc. of Fe trans. = 0.1, CMF_in = 0.8745, CMF_out = 0.297
# ⚠️ Skipping: Bound = 0.65, perc. = 0.15 → CMF > 1 (CMF_in = 1.147, CMF_out = 0.2805)
# ⚠️ Skipping: Bound = 0.65, perc. = 0.2 → CMF > 1 (CMF_in = 1.419, CMF_out = 0.264)
# ⚠️ Skipping: Bound = 0.65, perc. = 0.25 → CMF > 1 (CMF_in = 1.691, CMF_out = 0.2475)
# ⚠️ Skipping: Bound = 0.65, perc. = 0.3 → CMF > 1 (CMF_in = 1.964, CMF_out = 0.231)
# ⚠️ Skipping: Bound = 0.65, perc. = 0.35 → CMF > 1 (CMF_in = 2.236, CMF_out = 0.2145)
# ⚠️ Skipping: Bound = 0.65, perc. = 0.4 → CMF > 1 (CMF_in = 2.508, CMF_out = 0.198)
# ⚠️ Skipping: Bound = 0.65, perc. = 0.45 → CMF > 1 (CMF_in = 2.78, CMF_out = 0.1815)
# Output file: step_functions/cham_bi_tajer_step_b0.7_p0.05.txt
# Successfully generated 'step_functions/cham_bi_tajer_step_b0.7_p0.05.txt' with 154 entries.
# Bound = 0.7, perc. of Fe trans. = 0.05, CMF_in = 0.3786, CMF_out = 0.3135
# Output file: step_functions/cham_bi_tajer_step_b0.7_p0.1.txt
# Successfully generated 'step_functions/cham_bi_tajer_step_b0.7_p0.1.txt' with 154 entries.
# Bound = 0.7, perc. of Fe trans. = 0.1, CMF_in = 0.4271, CMF_out = 0.297
# Output file: step_functions/cham_bi_tajer_step_b0.7_p0.15.txt
# Successfully generated 'step_functions/cham_bi_tajer_step_b0.7_p0.15.txt' with 154 entries.
# Bound = 0.7, perc. of Fe trans. = 0.15, CMF_in = 0.4757, CMF_out = 0.2805
# Output file: step_functions/cham_bi_tajer_step_b0.7_p0.2.txt
# Successfully generated 'step_functions/cham_bi_tajer_step_b0.7_p0.2.txt' with 154 entries.
# Bound = 0.7, perc. of Fe trans. = 0.2, CMF_in = 0.5243, CMF_out = 0.264
# Output file: step_functions/cham_bi_tajer_step_b0.7_p0.25.txt
# Successfully generated 'step_functions/cham_bi_tajer_step_b0.7_p0.25.txt' with 154 entries.
# Bound = 0.7, perc. of Fe trans. = 0.25, CMF_in = 0.5729, CMF_out = 0.2475
# Output file: step_functions/cham_bi_tajer_step_b0.7_p0.3.txt
# Successfully generated 'step_functions/cham_bi_tajer_step_b0.7_p0.3.txt' with 154 entries.
# Bound = 0.7, perc. of Fe trans. = 0.3, CMF_in = 0.6214, CMF_out = 0.231
# Output file: step_functions/cham_bi_tajer_step_b0.7_p0.35.txt
# Successfully generated 'step_functions/cham_bi_tajer_step_b0.7_p0.35.txt' with 154 entries.
# Bound = 0.7, perc. of Fe trans. = 0.35, CMF_in = 0.67, CMF_out = 0.2145
# Output file: step_functions/cham_bi_tajer_step_b0.7_p0.4.txt
# Successfully generated 'step_functions/cham_bi_tajer_step_b0.7_p0.4.txt' with 154 entries.
# Bound = 0.7, perc. of Fe trans. = 0.4, CMF_in = 0.7186, CMF_out = 0.198
# Output file: step_functions/cham_bi_tajer_step_b0.7_p0.45.txt
# Successfully generated 'step_functions/cham_bi_tajer_step_b0.7_p0.45.txt' with 154 entries.
# Bound = 0.7, perc. of Fe trans. = 0.45, CMF_in = 0.7671, CMF_out = 0.1815
# Output file: step_functions/cham_bi_tajer_step_b0.75_p0.05.txt
# Successfully generated 'step_functions/cham_bi_tajer_step_b0.75_p0.05.txt' with 154 entries.
# Bound = 0.75, perc. of Fe trans. = 0.05, CMF_in = 0.3735, CMF_out = 0.3135
# Output file: step_functions/cham_bi_tajer_step_b0.75_p0.1.txt
# Successfully generated 'step_functions/cham_bi_tajer_step_b0.75_p0.1.txt' with 154 entries.
# Bound = 0.75, perc. of Fe trans. = 0.1, CMF_in = 0.417, CMF_out = 0.297
# Output file: step_functions/cham_bi_tajer_step_b0.75_p0.15.txt
# Successfully generated 'step_functions/cham_bi_tajer_step_b0.75_p0.15.txt' with 154 entries.
# Bound = 0.75, perc. of Fe trans. = 0.15, CMF_in = 0.4605, CMF_out = 0.2805
# Output file: step_functions/cham_bi_tajer_step_b0.75_p0.2.txt
# Successfully generated 'step_functions/cham_bi_tajer_step_b0.75_p0.2.txt' with 154 entries.
# Bound = 0.75, perc. of Fe trans. = 0.2, CMF_in = 0.504, CMF_out = 0.264
# Output file: step_functions/cham_bi_tajer_step_b0.75_p0.25.txt
# Successfully generated 'step_functions/cham_bi_tajer_step_b0.75_p0.25.txt' with 154 entries.
# Bound = 0.75, perc. of Fe trans. = 0.25, CMF_in = 0.5475, CMF_out = 0.2475
# Output file: step_functions/cham_bi_tajer_step_b0.75_p0.3.txt
# Successfully generated 'step_functions/cham_bi_tajer_step_b0.75_p0.3.txt' with 154 entries.
# Bound = 0.75, perc. of Fe trans. = 0.3, CMF_in = 0.591, CMF_out = 0.231
# Output file: step_functions/cham_bi_tajer_step_b0.75_p0.35.txt
# Successfully generated 'step_functions/cham_bi_tajer_step_b0.75_p0.35.txt' with 154 entries.
# Bound = 0.75, perc. of Fe trans. = 0.35, CMF_in = 0.6345, CMF_out = 0.2145
# Output file: step_functions/cham_bi_tajer_step_b0.75_p0.4.txt
# Successfully generated 'step_functions/cham_bi_tajer_step_b0.75_p0.4.txt' with 154 entries.
# Bound = 0.75, perc. of Fe trans. = 0.4, CMF_in = 0.678, CMF_out = 0.198
# Output file: step_functions/cham_bi_tajer_step_b0.75_p0.45.txt
# Successfully generated 'step_functions/cham_bi_tajer_step_b0.75_p0.45.txt' with 154 entries.
# Bound = 0.75, perc. of Fe trans. = 0.45, CMF_in = 0.7215, CMF_out = 0.1815
# Output file: step_functions/cham_bi_tajer_step_b0.8_p0.05.txt
# Successfully generated 'step_functions/cham_bi_tajer_step_b0.8_p0.05.txt' with 154 entries.
# Bound = 0.8, perc. of Fe trans. = 0.05, CMF_in = 0.3705, CMF_out = 0.3135
# Output file: step_functions/cham_bi_tajer_step_b0.8_p0.1.txt
# Successfully generated 'step_functions/cham_bi_tajer_step_b0.8_p0.1.txt' with 154 entries.
# Bound = 0.8, perc. of Fe trans. = 0.1, CMF_in = 0.4111, CMF_out = 0.297
# Output file: step_functions/cham_bi_tajer_step_b0.8_p0.15.txt
# Successfully generated 'step_functions/cham_bi_tajer_step_b0.8_p0.15.txt' with 154 entries.
# Bound = 0.8, perc. of Fe trans. = 0.15, CMF_in = 0.4516, CMF_out = 0.2805
# Output file: step_functions/cham_bi_tajer_step_b0.8_p0.2.txt
# Successfully generated 'step_functions/cham_bi_tajer_step_b0.8_p0.2.txt' with 154 entries.
# Bound = 0.8, perc. of Fe trans. = 0.2, CMF_in = 0.4921, CMF_out = 0.264
# Output file: step_functions/cham_bi_tajer_step_b0.8_p0.25.txt
# Successfully generated 'step_functions/cham_bi_tajer_step_b0.8_p0.25.txt' with 154 entries.
# Bound = 0.8, perc. of Fe trans. = 0.25, CMF_in = 0.5327, CMF_out = 0.2475
# Output file: step_functions/cham_bi_tajer_step_b0.8_p0.3.txt
# Successfully generated 'step_functions/cham_bi_tajer_step_b0.8_p0.3.txt' with 154 entries.
# Bound = 0.8, perc. of Fe trans. = 0.3, CMF_in = 0.5732, CMF_out = 0.231
# Output file: step_functions/cham_bi_tajer_step_b0.8_p0.35.txt
# Successfully generated 'step_functions/cham_bi_tajer_step_b0.8_p0.35.txt' with 154 entries.
# Bound = 0.8, perc. of Fe trans. = 0.35, CMF_in = 0.6138, CMF_out = 0.2145
# Output file: step_functions/cham_bi_tajer_step_b0.8_p0.4.txt
# Successfully generated 'step_functions/cham_bi_tajer_step_b0.8_p0.4.txt' with 154 entries.
# Bound = 0.8, perc. of Fe trans. = 0.4, CMF_in = 0.6543, CMF_out = 0.198
# Output file: step_functions/cham_bi_tajer_step_b0.8_p0.45.txt
# Successfully generated 'step_functions/cham_bi_tajer_step_b0.8_p0.45.txt' with 154 entries.
# Bound = 0.8, perc. of Fe trans. = 0.45, CMF_in = 0.6948, CMF_out = 0.1815

# %%
cmf_grid.to_csv("cham_bi_tajer_cmf_grid.csv", index=False)

# %%
for index, (semi, m) in enumerate(zip(semis_cham_bench, m_cham_bench)):
    print(f"Pair {index}: semi={semi}, m={m}")
# Out:
# Pair 0: semi=0.6614446540141468, m=2.8e-07
# Pair 1: semi=0.6656817404205098, m=2.8e-07
# Pair 2: semi=0.6732959670694759, m=2.8e-07
# Pair 3: semi=0.6837238484649418, m=2.8e-07
# Pair 4: semi=0.6966706667919996, m=2.8e-07
# Pair 5: semi=0.8360745638493606, m=2.8e-07
# Pair 6: semi=1.1216288976596727, m=2.8e-07
# Pair 7: semi=1.21870877418721, m=2.8e-07
# Pair 8: semi=1.2851651870579308, m=2.8e-07
# Pair 9: semi=1.3139303648390852, m=2.8e-07
# Pair 10: semi=1.454537438983013, m=2.8e-07
# Pair 11: semi=1.4586081642599056, m=2.8e-07
# Pair 12: semi=1.655267834181469, m=2.8e-07
# Pair 13: semi=1.7741010601524299, m=2.8e-07
# Pair 14: semi=0.37483525390025646, m=2.8e-08
# Pair 15: semi=0.45555470606122833, m=2.8e-08
# Pair 16: semi=0.4560875213763208, m=2.8e-08
# Pair 17: semi=0.47473205462935136, m=2.8e-08
# Pair 18: semi=0.530918043778436, m=2.8e-08
# Pair 19: semi=0.536106262977952, m=2.8e-08
# Pair 20: semi=0.5532263249645595, m=2.8e-08
# Pair 21: semi=0.5849831723535857, m=2.8e-08
# Pair 22: semi=0.5941644153785056, m=2.8e-08
# Pair 23: semi=0.5975508329990212, m=2.8e-08
# Pair 24: semi=0.5985804326134705, m=2.8e-08
# Pair 25: semi=0.6060406761589578, m=2.8e-08
# Pair 26: semi=0.6140372925879388, m=2.8e-08
# Pair 27: semi=0.6181556198699155, m=2.8e-08
# Pair 28: semi=0.6374694874174988, m=2.8e-08
# Pair 29: semi=0.6401541325477856, m=2.8e-08
# Pair 30: semi=0.6512730177563142, m=2.8e-08
# Pair 31: semi=0.659381979171922, m=2.8e-08
# Pair 32: semi=0.6701582125020934, m=2.8e-08
# Pair 33: semi=0.6825994626514986, m=2.8e-08
# Pair 34: semi=0.6897278309099676, m=2.8e-08
# Pair 35: semi=0.7135332588254978, m=2.8e-08
# Pair 36: semi=0.7173441622394785, m=2.8e-08
# Pair 37: semi=0.7205873024117015, m=2.8e-08
# Pair 38: semi=0.7242311490028661, m=2.8e-08
# Pair 39: semi=0.7366235832819719, m=2.8e-08
# Pair 40: semi=0.7440758505579976, m=2.8e-08
# Pair 41: semi=0.7525405491522383, m=2.8e-08
# Pair 42: semi=0.7545594954252336, m=2.8e-08
# Pair 43: semi=0.765802337260109, m=2.8e-08
# Pair 44: semi=0.7942723481384645, m=2.8e-08
# Pair 45: semi=0.8054411893850887, m=2.8e-08
# Pair 46: semi=0.8060833498070158, m=2.8e-08
# Pair 47: semi=0.8094538421024982, m=2.8e-08
# Pair 48: semi=0.8160623992540407, m=2.8e-08
# Pair 49: semi=0.8226940247534574, m=2.8e-08
# Pair 50: semi=0.8236638910948872, m=2.8e-08
# Pair 51: semi=0.8247082217881384, m=2.8e-08
# Pair 52: semi=0.832387803819906, m=2.8e-08
# Pair 53: semi=0.8331936431767591, m=2.8e-08
# Pair 54: semi=0.8421983563114198, m=2.8e-08
# Pair 55: semi=0.8459469976675273, m=2.8e-08
# Pair 56: semi=0.8459741633676463, m=2.8e-08
# Pair 57: semi=0.8483937097088656, m=2.8e-08
# Pair 58: semi=0.8559763984117862, m=2.8e-08
# Pair 59: semi=0.8563281186364691, m=2.8e-08
# Pair 60: semi=0.8681205200993807, m=2.8e-08
# Pair 61: semi=0.8691151556690947, m=2.8e-08
# Pair 62: semi=0.878952798573568, m=2.8e-08
# Pair 63: semi=0.8839705337732631, m=2.8e-08
# Pair 64: semi=0.9027119807760201, m=2.8e-08
# Pair 65: semi=0.9063823713335721, m=2.8e-08
# Pair 66: semi=0.9395399285037174, m=2.8e-08
# Pair 67: semi=0.940164749784876, m=2.8e-08
# Pair 68: semi=0.9428847142217422, m=2.8e-08
# Pair 69: semi=0.9474008999388834, m=2.8e-08
# Pair 70: semi=0.9522508912279545, m=2.8e-08
# Pair 71: semi=0.9600092989208, m=2.8e-08
# Pair 72: semi=0.9692275886679232, m=2.8e-08
# Pair 73: semi=0.9766282304718629, m=2.8e-08
# Pair 74: semi=1.0022034460836895, m=2.8e-08
# Pair 75: semi=1.0042005172412072, m=2.8e-08
# Pair 76: semi=1.009383213689763, m=2.8e-08
# Pair 77: semi=1.0210577199913191, m=2.8e-08
# Pair 78: semi=1.0320295685170946, m=2.8e-08
# Pair 79: semi=1.032042477819733, m=2.8e-08
# Pair 80: semi=1.0386177376189896, m=2.8e-08
# Pair 81: semi=1.0400424502139283, m=2.8e-08
# Pair 82: semi=1.0410465946771617, m=2.8e-08
# Pair 83: semi=1.1043645441724073, m=2.8e-08
# Pair 84: semi=1.1076875628911684, m=2.8e-08
# Pair 85: semi=1.1083275024494956, m=2.8e-08
# Pair 86: semi=1.132101721542405, m=2.8e-08
# Pair 87: semi=1.1369588350256958, m=2.8e-08
# Pair 88: semi=1.1555007229240968, m=2.8e-08
# Pair 89: semi=1.1636389604071098, m=2.8e-08
# Pair 90: semi=1.1720871352454014, m=2.8e-08
# Pair 91: semi=1.1836392757273624, m=2.8e-08
# Pair 92: semi=1.2073829231377315, m=2.8e-08
# Pair 93: semi=1.2245589634057765, m=2.8e-08
# Pair 94: semi=1.2518107092011441, m=2.8e-08
# Pair 95: semi=1.2675717036209655, m=2.8e-08
# Pair 96: semi=1.2724989201887396, m=2.8e-08
# Pair 97: semi=1.2748502548343337, m=2.8e-08
# Pair 98: semi=1.28625787191405, m=2.8e-08
# Pair 99: semi=1.291242476218349, m=2.8e-08
# Pair 100: semi=1.3069242575809057, m=2.8e-08
# Pair 101: semi=1.3389198259762318, m=2.8e-08
# Pair 102: semi=1.3393817565460844, m=2.8e-08
# Pair 103: semi=1.3742544163827144, m=2.8e-08
# Pair 104: semi=1.3878659544685252, m=2.8e-08
# Pair 105: semi=1.3923464069414282, m=2.8e-08
# Pair 106: semi=1.394540186931233, m=2.8e-08
# Pair 107: semi=1.3991002390158855, m=2.8e-08
# Pair 108: semi=1.4041934738323072, m=2.8e-08
# Pair 109: semi=1.4081776351097974, m=2.8e-08
# Pair 110: semi=1.4467629473455477, m=2.8e-08
# Pair 111: semi=1.4718180758971169, m=2.8e-08
# Pair 112: semi=1.4854852102292255, m=2.8e-08
# Pair 113: semi=1.487179265612033, m=2.8e-08
# Pair 114: semi=1.508092531539491, m=2.8e-08
# Pair 115: semi=1.5124304430645334, m=2.8e-08
# Pair 116: semi=1.5317373017129312, m=2.8e-08
# Pair 117: semi=1.562114883253624, m=2.8e-08
# Pair 118: semi=1.596338375664933, m=2.8e-08
# Pair 119: semi=1.606615092642117, m=2.8e-08
# Pair 120: semi=1.6077504748374465, m=2.8e-08
# Pair 121: semi=1.6104148952080335, m=2.8e-08
# Pair 122: semi=1.644905097380444, m=2.8e-08
# Pair 123: semi=1.6529034812014474, m=2.8e-08
# Pair 124: semi=1.6638495725553097, m=2.8e-08
# Pair 125: semi=1.6818576696403107, m=2.8e-08
# Pair 126: semi=1.6928221509053976, m=2.8e-08
# Pair 127: semi=1.6931774374411999, m=2.8e-08
# Pair 128: semi=1.6990301880323178, m=2.8e-08
# Pair 129: semi=1.711576157417867, m=2.8e-08
# Pair 130: semi=1.7238317827075236, m=2.8e-08
# Pair 131: semi=1.7310650579546827, m=2.8e-08
# Pair 132: semi=1.7316139346891488, m=2.8e-08
# Pair 133: semi=1.7336253899527585, m=2.8e-08
# Pair 134: semi=1.7642058431831305, m=2.8e-08
# Pair 135: semi=1.7893939576976474, m=2.8e-08
# Pair 136: semi=1.7897776770877583, m=2.8e-08
# Pair 137: semi=1.8003371406804716, m=2.8e-08
# Pair 138: semi=1.801023651852554, m=2.8e-08
# Pair 139: semi=1.8255803246825395, m=2.8e-08
# Pair 140: semi=1.8269614651852781, m=2.8e-08
# Pair 141: semi=1.8297250359048036, m=2.8e-08
# Pair 142: semi=1.8651526232230475, m=2.8e-08
# Pair 143: semi=1.8729832408749318, m=2.8e-08
# Pair 144: semi=1.8790553677406883, m=2.8e-08
# Pair 145: semi=1.8834187881712392, m=2.8e-08
# Pair 146: semi=1.892085221611482, m=2.8e-08
# Pair 147: semi=1.8968872523075062, m=2.8e-08
# Pair 148: semi=1.8981117757955743, m=2.8e-08
# Pair 149: semi=1.9237979647064967, m=2.8e-08
# Pair 150: semi=1.9281644629881018, m=2.8e-08
# Pair 151: semi=1.9452178915975438, m=2.8e-08
# Pair 152: semi=1.9542413184816474, m=2.8e-08
# Pair 153: semi=1.9875643557499159, m=2.8e-08
