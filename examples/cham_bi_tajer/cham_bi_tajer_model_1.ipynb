# %%
import os
import numpy as np
import pandas as pd
from coregiver import composition_tracker_v1 as ctv1

# %% [markdown]
# # Uniform, Earth CMF

# %%
# cham_bi_tajer loop, uniform
n_runs = 130 # This variable is not used in the loop, you might want to remove it
for i in range(n_runs):
    collision_file = f"/Users/honeyeah/Codes/data/cham_bi_tajer/cham_bi_tajer_{i+1}/collision_report.txt"
    comp_input_file = "/Users/honeyeah/Codes/coregiver/examples/cham_bi_tajer/uniform_33.txt"

    ejec_file = f"/Users/honeyeah/Codes/data/cham_bi_tajer/cham_bi_tajer_{i+1}/ejections.txt"

    if os.path.exists(ejec_file):
        print('ejections file found.', i)
    else:
        ejec_file = "/Users/honeyeah/Codes/planetgarten/body_composition_tracker/test_input/ejections_empty.txt"
        print("ejections file not found, using an empty file.", i)

    comp_output_file = f"/Users/honeyeah/Codes/data/cham_bi_tajer/cham_bi_tajer_{i+1}/uniform_33.txt"

    final_compositions = ctv1.track_composition(collision_file, comp_input_file, ejec_file)
    ctv1.write_output(final_compositions, comp_output_file)
    print(f"Processed Cham cont run {i+1}")
# Out:
# ejections file found. 0
# Processed Cham cont run 1
# ejections file found. 1
# Processed Cham cont run 2
# ejections file found. 2
# Processed Cham cont run 3
# ejections file found. 3
# Processed Cham cont run 4
# ejections file found. 4
# Processed Cham cont run 5
# ejections file not found, using an empty file. 5
# ERROR: Largest remnant CMF is greater than 1.0 at time:  22992260.0
# Processed Cham cont run 6
# ejections file found. 6
# Processed Cham cont run 7
# ejections file found. 7
# Processed Cham cont run 8
# ejections file found. 8
# Processed Cham cont run 9
# ejections file found. 9
# Processed Cham cont run 10
# ejections file found. 10
# Processed Cham cont run 11
# ejections file found. 11
# Processed Cham cont run 12
# ejections file found. 12
# Processed Cham cont run 13
# ejections file found. 13
# Processed Cham cont run 14
# ejections file found. 14
# Processed Cham cont run 15
# ejections file found. 15
# Processed Cham cont run 16
# ejections file found. 16
# ...

# %% [markdown]
# # Uniform, higher metallicity

# %%
# cham_bi_tajer loop, uniform
n_runs = 130 # This variable is not used in the loop, you might want to remove it
for i in range(n_runs):
    collision_file = f"/Users/honeyeah/Codes/data/cham_bi_tajer/cham_bi_tajer_{i+1}/collision_report.txt"
    comp_input_file = "/Users/honeyeah/Codes/coregiver/examples/cham_bi_tajer/uniform_40.txt"

    ejec_file = f"/Users/honeyeah/Codes/data/cham_bi_tajer/cham_bi_tajer_{i+1}/ejections.txt"

    if os.path.exists(ejec_file):
        print('ejections file found.', i)
    else:
        ejec_file = "/Users/honeyeah/Codes/planetgarten/body_composition_tracker/test_input/ejections_empty.txt"
        print("ejections file not found, using an empty file.", i)

    comp_output_file = f"/Users/honeyeah/Codes/data/cham_bi_tajer/cham_bi_tajer_{i+1}/uniform_40.txt"

    final_compositions = ctv1.track_composition(collision_file, comp_input_file, ejec_file)
    ctv1.write_output(final_compositions, comp_output_file)
    print(f"Processed Cham bench run {i+1}")
# Out:
# ejections file found. 0
# Processed Cham bench run 1
# ejections file found. 1
# Processed Cham bench run 2
# ejections file found. 2
# Processed Cham bench run 3
# ejections file found. 3
# Processed Cham bench run 4
# ejections file found. 4
# Processed Cham bench run 5
# ejections file not found, using an empty file. 5
# ERROR: Largest remnant CMF is greater than 1.0 at time:  22992260.0
# Processed Cham bench run 6
# ejections file found. 6
# Processed Cham bench run 7
# ejections file found. 7
# Processed Cham bench run 8
# ejections file found. 8
# Processed Cham bench run 9
# ejections file found. 9
# Processed Cham bench run 10
# ejections file found. 10
# Processed Cham bench run 11
# ejections file found. 11
# Processed Cham bench run 12
# ejections file found. 12
# Processed Cham bench run 13
# ejections file found. 13
# Processed Cham bench run 14
# ejections file found. 14
# Processed Cham bench run 15
# ejections file found. 15
# Processed Cham bench run 16
# ...

# %% [markdown]
# # Step functions

# %%
# cham_bi_tajer loop, for the step functions
cmf_grid = pd.read_csv('/Users/honeyeah/Codes/coregiver/examples/cham_bi_tajer/cham_bi_tajer_cmf_grid.csv')
bounds = cmf_grid['bounds']
percentages = cmf_grid['percentages']
n_runs = 130 # This variable is not used in the loop, you might want to remove it
for i in range(n_runs):
    for _, row in cmf_grid.iterrows():
        bound = row['bounds']
        perc = row['percentages']

        collision_file = f"/Users/honeyeah/Codes/data/cham_bi_tajer/cham_bi_tajer_{i+1}/collision_report.txt"
        comp_input_file = f"/Users/honeyeah/Codes/coregiver/examples/cham_bi_tajer/step_functions/cham_bi_tajer_step_b{bound}_p{perc}.txt"

        ejec_file = f"/Users/honeyeah/Codes/data/cham_bi_tajer/cham_bi_tajer_{i+1}/ejections.txt"

        if os.path.exists(ejec_file):
            print('ejections file found.', i)
        else:
            ejec_file = "/Users/honeyeah/Codes/planetgarten/body_composition_tracker/test_input/ejections_empty.txt"
            print("ejections file not found, using an empty file.", i)

        comp_output_file = f"/Users/honeyeah/Codes/data/cham_bi_tajer/cham_bi_tajer_{i+1}/cham_bi_tajer_output_step_b{bound}_p{perc}.txt"

        final_compositions = ctv1.track_composition(collision_file, comp_input_file, ejec_file)
        ctv1.write_output(final_compositions, comp_output_file)
        print(f"Processed cham_bi_tajer run {i+1}")
# Out:
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ...

# %% [markdown]
# If you got errors, this will skip problematic ones

# %%
import os
import pandas as pd


cmf_grid = pd.read_csv('/Users/honeyeah/Codes/coregiver/examples/cham_bi_tajer/cham_bi_tajer_cmf_grid.csv')
bounds = cmf_grid['bounds']
percentages = cmf_grid['percentages']
n_runs = 100  # This variable is not used in the loop, you might want to remove it

for i in range(n_runs):
    for _, row in cmf_grid.iterrows():
        bound = row['bounds']
        perc = row['percentages']

        collision_file = f"/Users/honeyeah/Codes/data/cham_bi_tajer/cham_bi_tajer_{i+1}/collision_report.txt"
        comp_input_file = f"/Users/honeyeah/Codes/coregiver/examples/cham_bi_tajer/step_functions/cham_bi_tajer_step_b{bound}_p{perc}.txt"

        ejec_file = f"/Users/honeyeah/Codes/data/cham_bi_tajer/cham_bi_tajer_{i+1}/ejections.txt"

        if os.path.exists(ejec_file):
            print('ejections file found.', i)
        else:
            ejec_file = "/Users/honeyeah/Codes/planetgarten/body_composition_tracker/test_input/ejections_empty.txt"
            print("ejections file not found, using an empty file.", i)

        comp_output_file = f"/Users/honeyeah/Codes/data/cham_bi_tajer/cham_bi_tajer_{i+1}/cham_bi_tajer_output_step_b{bound}_p{perc}.txt"

        try:
            final_compositions = ctv1.track_composition(collision_file, comp_input_file, ejec_file)
            ctv1.write_output(final_compositions, comp_output_file)
            print(f"Processed cham_bi_tajer run {i+1}")
        except Exception as e:
            print(f"Skipped cham_bi_tajer run {i+1} due to error: {e}")
            continue
# Out:
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ejections file found. 0
# Processed cham_bi_tajer run 1
# ...

# %%
#Exp
n_runs = 100 # This variable is not used in the loop, you might want to remove it
for i in range(n_runs):
    collision_file = f"/Users/honeyeah/Codes/data/cham_bi_tajer/cham_bi_tajer_{i+1}/collision_report.txt"
    comp_input_file = "/Users/honeyeah/Codes/coregiver/examples/cham_bi_tajer/exp_cham_bi.txt"

    ejec_file = f"/Users/honeyeah/Codes/data/cham_bi_tajer/cham_bi_tajer_{i+1}/ejections.txt"

    if os.path.exists(ejec_file):
        print('ejections file found.', i)
    else:
        ejec_file = "/Users/honeyeah/Codes/planetgarten/body_composition_tracker/test_input/ejections_empty.txt"
        print("ejections file not found, using an empty file.", i)

    comp_output_file = f"/Users/honeyeah/Codes/data/cham_bi_tajer/cham_bi_tajer_{i+1}/exp.txt"

    final_compositions = ctv1.track_composition(collision_file, comp_input_file, ejec_file)
    ctv1.write_output(final_compositions, comp_output_file)
    print(f"Processed Cham bench run {i+1}")
# Out:
# ejections file found. 0
# Processed Cham bench run 1
# ejections file found. 1
# Processed Cham bench run 2
# ejections file found. 2
# Processed Cham bench run 3
# ejections file found. 3
# Processed Cham bench run 4
# ejections file found. 4
# Processed Cham bench run 5
# ejections file not found, using an empty file. 5
# ERROR: Largest remnant CMF is greater than 1.0 at time:  22992260.0
# Processed Cham bench run 6
# ejections file found. 6
# Processed Cham bench run 7
# ejections file found. 7
# Processed Cham bench run 8
# ejections file found. 8
# Processed Cham bench run 9
# ejections file found. 9
# Processed Cham bench run 10
# ejections file found. 10
# Processed Cham bench run 11
# ejections file found. 11
# Processed Cham bench run 12
# ejections file found. 12
# Processed Cham bench run 13
# ejections file found. 13
# Processed Cham bench run 14
# ejections file found. 14
# Processed Cham bench run 15
# ejections file found. 15
# Processed Cham bench run 16
# ...
