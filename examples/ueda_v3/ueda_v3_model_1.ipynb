# %%
import os
import numpy as np
import pandas as pd
from coregiver import composition_tracker_v1 as ctv1

# %% [markdown]
# # Uniform, Earth CMF

# %%
# Ueda_v3 loop, uniform
n_runs = 10 # This variable is not used in the loop, you might want to remove it
for i in range(35):
    if i == 26:
        continue 
    collision_file = f"/Users/honeyeah/Codes/data/ueda_v3/ueda_v3_{i+1}/collision_report.txt"
    comp_input_file = "/Users/honeyeah/Codes/coregiver/examples/ueda_v3/uniform_33.txt"

    ejec_file = f"/Users/honeyeah/Codes/data/ueda_v3/ueda_v3_{i+1}/ejections.txt"

    if os.path.exists(ejec_file):
        print('ejections file found.', i)
    else:
        ejec_file = "/Users/honeyeah/Codes/planetgarten/body_composition_tracker/test_input/ejections_empty.txt"
        print("ejections file not found, using an empty file.", i)

    comp_output_file = f"/Users/honeyeah/Codes/data/ueda_v3/ueda_v3_{i+1}/uniform_33.txt"

    final_compositions = ctv1.track_composition(collision_file, comp_input_file, ejec_file)
    ctv1.write_output(final_compositions, comp_output_file)
    print(f"Processed Ueda V3 run {i+1}")
# Out:
# ejections file found. 0
# Processed Ueda V3 run 1
# ejections file found. 1
# Processed Ueda V3 run 2
# ejections file found. 2
# Processed Ueda V3 run 3
# ejections file not found, using an empty file. 3
# Processed Ueda V3 run 4
# ejections file found. 4
# Processed Ueda V3 run 5
# ejections file found. 5
# Processed Ueda V3 run 6
# ejections file not found, using an empty file. 6
# Processed Ueda V3 run 7
# ejections file not found, using an empty file. 7
# Processed Ueda V3 run 8
# ejections file found. 8
# Processed Ueda V3 run 9
# ejections file found. 9
# Processed Ueda V3 run 10
# ejections file found. 10
# Processed Ueda V3 run 11
# ejections file found. 11
# Processed Ueda V3 run 12
# ejections file found. 12
# Processed Ueda V3 run 13
# ejections file found. 13
# Processed Ueda V3 run 14
# ejections file found. 14
# Processed Ueda V3 run 15
# ejections file found. 15
# Processed Ueda V3 run 16
# ejections file found. 16
# Processed Ueda V3 run 17
# ...

# %% [markdown]
# # Uniform, higher metallicity

# %%
# Ueda_v3 loop, uniform
n_runs = 10 # This variable is not used in the loop, you might want to remove it
for i in range(n_runs):
    collision_file = f"/Users/honeyeah/Codes/data/ueda_v3/ueda_v3_{i+1}/collision_report.txt"
    comp_input_file = "/Users/honeyeah/Codes/coregiver/examples/ueda_v3/uniform_40.txt"

    ejec_file = f"/Users/honeyeah/Codes/data/ueda_v3/ueda_v3_{i+1}/ejections.txt"

    if os.path.exists(ejec_file):
        print('ejections file found.', i)
    else:
        ejec_file = "/Users/honeyeah/Codes/planetgarten/body_composition_tracker/test_input/ejections_empty.txt"
        print("ejections file not found, using an empty file.", i)

    comp_output_file = f"/Users/honeyeah/Codes/data/ueda_v3/ueda_v3_{i+1}/uniform_40.txt"

    final_compositions = ctv1.track_composition(collision_file, comp_input_file, ejec_file)
    ctv1.write_output(final_compositions, comp_output_file)
    print(f"Processed Ueda V3 run {i+1}")
# Out:
# ejections file found. 0
# Processed Ueda V3 run 1
# ejections file found. 1
# Processed Ueda V3 run 2
# ejections file found. 2
# Processed Ueda V3 run 3
# ejections file not found, using an empty file. 3
# Processed Ueda V3 run 4
# ejections file found. 4
# Processed Ueda V3 run 5
# ejections file found. 5
# Processed Ueda V3 run 6
# ejections file not found, using an empty file. 6
# Processed Ueda V3 run 7
# ejections file not found, using an empty file. 7
# Processed Ueda V3 run 8
# ejections file found. 8
# Processed Ueda V3 run 9
# ejections file found. 9
# Processed Ueda V3 run 10

# %% [markdown]
# # Step functions

# %%
# Ueda_v3 loop, for the step functions
cmf_grid = pd.read_csv('/Users/honeyeah/Codes/coregiver/examples/ueda_v3/ueda_v3_cmf_grid.csv')
bounds = cmf_grid['bounds']
percentages = cmf_grid['percentages']
n_runs = 10 # This variable is not used in the loop, you might want to remove it
for i in range(n_runs):
    for _, row in cmf_grid.iterrows():
        bound = row['bounds']
        perc = row['percentages']

        collision_file = f"/Users/honeyeah/Codes/data/ueda_v3/ueda_v3_{i+1}/collision_report.txt"
        comp_input_file = f"step_functions/ueda_v3_step_b{bound}_p{perc}.txt"

        ejec_file = f"/Users/honeyeah/Codes/data/ueda_v3/ueda_v3_{i+1}/ejections.txt"

        if os.path.exists(ejec_file):
            print('ejections file found.', i)
        else:
            ejec_file = "/Users/honeyeah/Codes/planetgarten/body_composition_tracker/test_input/ejections_empty.txt"
            print("ejections file not found, using an empty file.", i)

        comp_output_file = f"/Users/honeyeah/Codes/data/ueda_v3/ueda_v3_{i+1}/uv3_output_step_b{bound}_p{perc}.txt"

        final_compositions = ctv1.track_composition(collision_file, comp_input_file, ejec_file)
        ctv1.write_output(final_compositions, comp_output_file)
        print(f"Processed Ueda_v3 run {i+1}")
# Out:
# ejections file found. 0
# Processed Ueda_v3 run 1
# ejections file found. 0
# Processed Ueda_v3 run 1
# ejections file found. 0
# Processed Ueda_v3 run 1
# ejections file found. 0
# Processed Ueda_v3 run 1
# ejections file found. 0
# Processed Ueda_v3 run 1
# ejections file found. 0
# Processed Ueda_v3 run 1
# ejections file found. 0
# Processed Ueda_v3 run 1
# ejections file found. 0
# Processed Ueda_v3 run 1
# ejections file found. 0
# Processed Ueda_v3 run 1
# ejections file found. 0
# Processed Ueda_v3 run 1
# ejections file found. 0
# Processed Ueda_v3 run 1
# ejections file found. 0
# Processed Ueda_v3 run 1
# ejections file found. 0
# Processed Ueda_v3 run 1
# ejections file found. 0
# Processed Ueda_v3 run 1
# ejections file found. 0
# Processed Ueda_v3 run 1
# ejections file found. 0
# Processed Ueda_v3 run 1
# ejections file found. 1
# Processed Ueda_v3 run 2
# ejections file found. 1
# Processed Ueda_v3 run 2
# ejections file found. 1
# Processed Ueda_v3 run 2
# ...
