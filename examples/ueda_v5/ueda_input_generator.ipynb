# %%
from coregiver import input_maker
import os # Needed for checking file existence and content
import numpy as np
import pandas as pd

# 2. Define your parameters
n_ueda_v5 = 150
m_ueda_v5 = 4.405e-8 #solMass
cmf_uni = 0.33
output_file_example = "examples/ueda_v5/uniform_33.txt"

# 3. Call the function to generate the file
input_maker.generate_input_uniform(n_ueda_v5, m_ueda_v5, cmf_uni, output_file_example)

# 4. (Optional) Verify the file was created and inspect its content
print(f"\nChecking if '{output_file_example}' exists...")
if os.path.exists(output_file_example):
    print(f"File '{output_file_example}' found!")
    print("\nFirst 5 lines of the generated file:")
    with open(output_file_example, 'r') as f:
        for _ in range(6): # Read header + 5 data lines
            line = f.readline()
            if not line:
                break
            print(line.strip())
else:
    print(f"File '{output_file_example}' was NOT found.")
# Out:
# Generating 150 particles with CMF=0.33...
# Output file: examples/ueda_v5/uniform_33.txt
# Error writing to file 'examples/ueda_v5/uniform_33.txt': [Errno 2] No such file or directory: 'examples/ueda_v5/uniform_33.txt'
#
# Checking if 'examples/ueda_v5/uniform_33.txt' exists...
# File 'examples/ueda_v5/uniform_33.txt' was NOT found.

# %%
from coregiver import input_maker
import os # Needed for checking file existence and content
import numpy as np
import pandas as pd

# 2. Define your parameters
n_ueda_v5 = 150
m_ueda_v5 = 4.405e-8 #solMass
cmf_uni = 0.4
output_file_example = "uniform_40.txt"

# 3. Call the function to generate the file
input_maker.generate_input_uniform(n_ueda_v5, m_ueda_v5, cmf_uni, output_file_example)

# 4. (Optional) Verify the file was created and inspect its content
print(f"\nChecking if '{output_file_example}' exists...")
if os.path.exists(output_file_example):
    print(f"File '{output_file_example}' found!")
    print("\nFirst 5 lines of the generated file:")
    with open(output_file_example, 'r') as f:
        for _ in range(6): # Read header + 5 data lines
            line = f.readline()
            if not line:
                break
            print(line.strip())
else:
    print(f"File '{output_file_example}' was NOT found.")
# Out:
# Generating 150 particles with CMF=0.4...
# Output file: uniform_40.txt
# Successfully generated 'uniform_40.txt' with 150 entries.
#
# Checking if 'uniform_40.txt' exists...
# File 'uniform_40.txt' found!
#
# First 5 lines of the generated file:
# 1	4.40500000e-08	4.00000000e-01
# 2	4.40500000e-08	4.00000000e-01
# 3	4.40500000e-08	4.00000000e-01
# 4	4.40500000e-08	4.00000000e-01
# 5	4.40500000e-08	4.00000000e-01
# 6	4.40500000e-08	4.00000000e-01

# %% [markdown]
# # Step-function input example

# %%
semis_ueda_v5 = np.loadtxt('/Users/honeyeah/Codes/coregiver/examples/ueda_v5/ueda_2021_v5.txt')

# %%
#Ueda V3 example

percentages = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45]
bounds = [0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8]
n_ueda_v5 = 150
m_ueda_v5 = 4.405e-8 #solMass
base_cmf = 0.33
semis_ueda_v5 = np.loadtxt('/Users/honeyeah/Codes/coregiver/examples/ueda_v5/ueda_2021_v5.txt')

cmf_grid = pd.DataFrame(columns=['bounds', 'percentages', 'inner_cmf', 'outer_cmf'])
grid_index = 0

for bound in bounds:
    for perc in percentages:
        cmf1, cmf2 = input_maker.get_dual_cmf_all_pl(m_ueda_v5, semis_ueda_v5, bound, perc, base_cmf)

        # Skip if any CMF > 1
        if cmf1 > 1 or cmf2 > 1:
            print(f"⚠️ Skipping: Bound = {bound}, perc. = {perc} → CMF > 1 (CMF_in = {cmf1:.4}, CMF_out = {cmf2:.4})")
            continue

        input_maker.generate_input_step_function(
            n_ueda_v5, m_ueda_v5, semis_ueda_v5, cmf1, cmf2, bound,
            f"step_functions/ueda_v5_step_b{bound}_p{perc}.txt"
        )

        cmf_grid.loc[grid_index] = {
            'bounds': bound,
            'percentages': perc,
            'inner_cmf': cmf1,
            'outer_cmf': cmf2
        }

        print(f"Bound = {bound}, perc. of Fe trans. = {perc}, CMF_in = {cmf1:.4}, CMF_out = {cmf2:.4}")
        grid_index += 1
# Out:
# ⚠️ Skipping: Bound = 0.5, perc. = 0.05 → CMF > 1 (CMF_in = inf, CMF_out = 0.3135)
# ⚠️ Skipping: Bound = 0.5, perc. = 0.1 → CMF > 1 (CMF_in = inf, CMF_out = 0.297)
# ⚠️ Skipping: Bound = 0.5, perc. = 0.15 → CMF > 1 (CMF_in = inf, CMF_out = 0.2805)
# ⚠️ Skipping: Bound = 0.5, perc. = 0.2 → CMF > 1 (CMF_in = inf, CMF_out = 0.264)
# ⚠️ Skipping: Bound = 0.5, perc. = 0.25 → CMF > 1 (CMF_in = inf, CMF_out = 0.2475)
# ⚠️ Skipping: Bound = 0.5, perc. = 0.3 → CMF > 1 (CMF_in = inf, CMF_out = 0.231)
# ⚠️ Skipping: Bound = 0.5, perc. = 0.35 → CMF > 1 (CMF_in = inf, CMF_out = 0.2145)
# ⚠️ Skipping: Bound = 0.5, perc. = 0.4 → CMF > 1 (CMF_in = inf, CMF_out = 0.198)
# ⚠️ Skipping: Bound = 0.5, perc. = 0.45 → CMF > 1 (CMF_in = inf, CMF_out = 0.1815)
# ⚠️ Skipping: Bound = 0.55, perc. = 0.05 → CMF > 1 (CMF_in = 2.789, CMF_out = 0.3135)
# ⚠️ Skipping: Bound = 0.55, perc. = 0.1 → CMF > 1 (CMF_in = 5.247, CMF_out = 0.297)
# ⚠️ Skipping: Bound = 0.55, perc. = 0.15 → CMF > 1 (CMF_in = 7.706, CMF_out = 0.2805)
# ⚠️ Skipping: Bound = 0.55, perc. = 0.2 → CMF > 1 (CMF_in = 10.16, CMF_out = 0.264)
# ⚠️ Skipping: Bound = 0.55, perc. = 0.25 → CMF > 1 (CMF_in = 12.62, CMF_out = 0.2475)
# ⚠️ Skipping: Bound = 0.55, perc. = 0.3 → CMF > 1 (CMF_in = 15.08, CMF_out = 0.231)
# ⚠️ Skipping: Bound = 0.55, perc. = 0.35 → CMF > 1 (CMF_in = 17.54, CMF_out = 0.2145)
# ⚠️ Skipping: Bound = 0.55, perc. = 0.4 → CMF > 1 (CMF_in = 20.0, CMF_out = 0.198)
# ⚠️ Skipping: Bound = 0.55, perc. = 0.45 → CMF > 1 (CMF_in = 22.46, CMF_out = 0.1815)
# Output file: step_functions/ueda_v5_step_b0.6_p0.05.txt
# Successfully generated 'step_functions/ueda_v5_step_b0.6_p0.05.txt' with 150 entries.
# Bound = 0.6, perc. of Fe trans. = 0.05, CMF_in = 0.9323, CMF_out = 0.3135
# ⚠️ Skipping: Bound = 0.6, perc. = 0.1 → CMF > 1 (CMF_in = 1.535, CMF_out = 0.297)
# ⚠️ Skipping: Bound = 0.6, perc. = 0.15 → CMF > 1 (CMF_in = 2.137, CMF_out = 0.2805)
# ⚠️ Skipping: Bound = 0.6, perc. = 0.2 → CMF > 1 (CMF_in = 2.739, CMF_out = 0.264)
# ⚠️ Skipping: Bound = 0.6, perc. = 0.25 → CMF > 1 (CMF_in = 3.341, CMF_out = 0.2475)
# ⚠️ Skipping: Bound = 0.6, perc. = 0.3 → CMF > 1 (CMF_in = 3.944, CMF_out = 0.231)
# ⚠️ Skipping: Bound = 0.6, perc. = 0.35 → CMF > 1 (CMF_in = 4.546, CMF_out = 0.2145)
# ⚠️ Skipping: Bound = 0.6, perc. = 0.4 → CMF > 1 (CMF_in = 5.148, CMF_out = 0.198)
# ⚠️ Skipping: Bound = 0.6, perc. = 0.45 → CMF > 1 (CMF_in = 5.75, CMF_out = 0.1815)
# Output file: step_functions/ueda_v5_step_b0.65_p0.05.txt
# Successfully generated 'step_functions/ueda_v5_step_b0.65_p0.05.txt' with 150 entries.
# Bound = 0.65, perc. of Fe trans. = 0.05, CMF_in = 0.5885, CMF_out = 0.3135
# Output file: step_functions/ueda_v5_step_b0.65_p0.1.txt
# Successfully generated 'step_functions/ueda_v5_step_b0.65_p0.1.txt' with 150 entries.
# Bound = 0.65, perc. of Fe trans. = 0.1, CMF_in = 0.847, CMF_out = 0.297
# ⚠️ Skipping: Bound = 0.65, perc. = 0.15 → CMF > 1 (CMF_in = 1.106, CMF_out = 0.2805)
# ⚠️ Skipping: Bound = 0.65, perc. = 0.2 → CMF > 1 (CMF_in = 1.364, CMF_out = 0.264)
# ⚠️ Skipping: Bound = 0.65, perc. = 0.25 → CMF > 1 (CMF_in = 1.623, CMF_out = 0.2475)
# ⚠️ Skipping: Bound = 0.65, perc. = 0.3 → CMF > 1 (CMF_in = 1.881, CMF_out = 0.231)
# ⚠️ Skipping: Bound = 0.65, perc. = 0.35 → CMF > 1 (CMF_in = 2.14, CMF_out = 0.2145)
# ⚠️ Skipping: Bound = 0.65, perc. = 0.4 → CMF > 1 (CMF_in = 2.398, CMF_out = 0.198)
# ⚠️ Skipping: Bound = 0.65, perc. = 0.45 → CMF > 1 (CMF_in = 2.657, CMF_out = 0.1815)
# Output file: step_functions/ueda_v5_step_b0.7_p0.05.txt
# Successfully generated 'step_functions/ueda_v5_step_b0.7_p0.05.txt' with 150 entries.
# Bound = 0.7, perc. of Fe trans. = 0.05, CMF_in = 0.396, CMF_out = 0.3135
# Output file: step_functions/ueda_v5_step_b0.7_p0.1.txt
# Successfully generated 'step_functions/ueda_v5_step_b0.7_p0.1.txt' with 150 entries.
# Bound = 0.7, perc. of Fe trans. = 0.1, CMF_in = 0.462, CMF_out = 0.297
# Output file: step_functions/ueda_v5_step_b0.7_p0.15.txt
# Successfully generated 'step_functions/ueda_v5_step_b0.7_p0.15.txt' with 150 entries.
# Bound = 0.7, perc. of Fe trans. = 0.15, CMF_in = 0.528, CMF_out = 0.2805
# Output file: step_functions/ueda_v5_step_b0.7_p0.2.txt
# Successfully generated 'step_functions/ueda_v5_step_b0.7_p0.2.txt' with 150 entries.
# Bound = 0.7, perc. of Fe trans. = 0.2, CMF_in = 0.594, CMF_out = 0.264
# Output file: step_functions/ueda_v5_step_b0.7_p0.25.txt
# Successfully generated 'step_functions/ueda_v5_step_b0.7_p0.25.txt' with 150 entries.
# Bound = 0.7, perc. of Fe trans. = 0.25, CMF_in = 0.66, CMF_out = 0.2475
# Output file: step_functions/ueda_v5_step_b0.7_p0.3.txt
# Successfully generated 'step_functions/ueda_v5_step_b0.7_p0.3.txt' with 150 entries.
# Bound = 0.7, perc. of Fe trans. = 0.3, CMF_in = 0.726, CMF_out = 0.231
# Output file: step_functions/ueda_v5_step_b0.7_p0.35.txt
# Successfully generated 'step_functions/ueda_v5_step_b0.7_p0.35.txt' with 150 entries.
# Bound = 0.7, perc. of Fe trans. = 0.35, CMF_in = 0.792, CMF_out = 0.2145
# Output file: step_functions/ueda_v5_step_b0.7_p0.4.txt
# Successfully generated 'step_functions/ueda_v5_step_b0.7_p0.4.txt' with 150 entries.
# Bound = 0.7, perc. of Fe trans. = 0.4, CMF_in = 0.858, CMF_out = 0.198
# Output file: step_functions/ueda_v5_step_b0.7_p0.45.txt
# Successfully generated 'step_functions/ueda_v5_step_b0.7_p0.45.txt' with 150 entries.
# Bound = 0.7, perc. of Fe trans. = 0.45, CMF_in = 0.924, CMF_out = 0.1815
# Output file: step_functions/ueda_v5_step_b0.75_p0.05.txt
# Successfully generated 'step_functions/ueda_v5_step_b0.75_p0.05.txt' with 150 entries.
# Bound = 0.75, perc. of Fe trans. = 0.05, CMF_in = 0.363, CMF_out = 0.3135
# Output file: step_functions/ueda_v5_step_b0.75_p0.1.txt
# Successfully generated 'step_functions/ueda_v5_step_b0.75_p0.1.txt' with 150 entries.
# Bound = 0.75, perc. of Fe trans. = 0.1, CMF_in = 0.396, CMF_out = 0.297
# Output file: step_functions/ueda_v5_step_b0.75_p0.15.txt
# Successfully generated 'step_functions/ueda_v5_step_b0.75_p0.15.txt' with 150 entries.
# Bound = 0.75, perc. of Fe trans. = 0.15, CMF_in = 0.429, CMF_out = 0.2805
# Output file: step_functions/ueda_v5_step_b0.75_p0.2.txt
# Successfully generated 'step_functions/ueda_v5_step_b0.75_p0.2.txt' with 150 entries.
# Bound = 0.75, perc. of Fe trans. = 0.2, CMF_in = 0.462, CMF_out = 0.264
# Output file: step_functions/ueda_v5_step_b0.75_p0.25.txt
# Successfully generated 'step_functions/ueda_v5_step_b0.75_p0.25.txt' with 150 entries.
# Bound = 0.75, perc. of Fe trans. = 0.25, CMF_in = 0.495, CMF_out = 0.2475
# Output file: step_functions/ueda_v5_step_b0.75_p0.3.txt
# Successfully generated 'step_functions/ueda_v5_step_b0.75_p0.3.txt' with 150 entries.
# Bound = 0.75, perc. of Fe trans. = 0.3, CMF_in = 0.528, CMF_out = 0.231
# Output file: step_functions/ueda_v5_step_b0.75_p0.35.txt
# Successfully generated 'step_functions/ueda_v5_step_b0.75_p0.35.txt' with 150 entries.
# Bound = 0.75, perc. of Fe trans. = 0.35, CMF_in = 0.561, CMF_out = 0.2145
# Output file: step_functions/ueda_v5_step_b0.75_p0.4.txt
# Successfully generated 'step_functions/ueda_v5_step_b0.75_p0.4.txt' with 150 entries.
# Bound = 0.75, perc. of Fe trans. = 0.4, CMF_in = 0.594, CMF_out = 0.198
# Output file: step_functions/ueda_v5_step_b0.75_p0.45.txt
# Successfully generated 'step_functions/ueda_v5_step_b0.75_p0.45.txt' with 150 entries.
# Bound = 0.75, perc. of Fe trans. = 0.45, CMF_in = 0.627, CMF_out = 0.1815
# Output file: step_functions/ueda_v5_step_b0.8_p0.05.txt
# Successfully generated 'step_functions/ueda_v5_step_b0.8_p0.05.txt' with 150 entries.
# Bound = 0.8, perc. of Fe trans. = 0.05, CMF_in = 0.3437, CMF_out = 0.3135
# Output file: step_functions/ueda_v5_step_b0.8_p0.1.txt
# Successfully generated 'step_functions/ueda_v5_step_b0.8_p0.1.txt' with 150 entries.
# Bound = 0.8, perc. of Fe trans. = 0.1, CMF_in = 0.3574, CMF_out = 0.297
# Output file: step_functions/ueda_v5_step_b0.8_p0.15.txt
# Successfully generated 'step_functions/ueda_v5_step_b0.8_p0.15.txt' with 150 entries.
# Bound = 0.8, perc. of Fe trans. = 0.15, CMF_in = 0.371, CMF_out = 0.2805
# Output file: step_functions/ueda_v5_step_b0.8_p0.2.txt
# Successfully generated 'step_functions/ueda_v5_step_b0.8_p0.2.txt' with 150 entries.
# Bound = 0.8, perc. of Fe trans. = 0.2, CMF_in = 0.3847, CMF_out = 0.264
# Output file: step_functions/ueda_v5_step_b0.8_p0.25.txt
# Successfully generated 'step_functions/ueda_v5_step_b0.8_p0.25.txt' with 150 entries.
# Bound = 0.8, perc. of Fe trans. = 0.25, CMF_in = 0.3984, CMF_out = 0.2475
# Output file: step_functions/ueda_v5_step_b0.8_p0.3.txt
# Successfully generated 'step_functions/ueda_v5_step_b0.8_p0.3.txt' with 150 entries.
# Bound = 0.8, perc. of Fe trans. = 0.3, CMF_in = 0.4121, CMF_out = 0.231
# Output file: step_functions/ueda_v5_step_b0.8_p0.35.txt
# Successfully generated 'step_functions/ueda_v5_step_b0.8_p0.35.txt' with 150 entries.
# Bound = 0.8, perc. of Fe trans. = 0.35, CMF_in = 0.4258, CMF_out = 0.2145
# Output file: step_functions/ueda_v5_step_b0.8_p0.4.txt
# Successfully generated 'step_functions/ueda_v5_step_b0.8_p0.4.txt' with 150 entries.
# Bound = 0.8, perc. of Fe trans. = 0.4, CMF_in = 0.4395, CMF_out = 0.198
# Output file: step_functions/ueda_v5_step_b0.8_p0.45.txt
# Successfully generated 'step_functions/ueda_v5_step_b0.8_p0.45.txt' with 150 entries.
# Bound = 0.8, perc. of Fe trans. = 0.45, CMF_in = 0.4531, CMF_out = 0.1815
# /Users/honeyeah/Codes/coregiver/coregiver/input_maker.py:123: RuntimeWarning: divide by zero encountered in scalar divide
#   cmf_inner_new = (cmf_initial * m_inner + iron_moved)/m_inner
# /Users/honeyeah/Codes/coregiver/coregiver/input_maker.py:127: RuntimeWarning: invalid value encountered in scalar multiply
#   m_Fe_final = cmf_inner_new * m_inner + cmf_outer_new * m_outer

# %%
cmf_grid.to_csv("ueda_v5_cmf_grid.csv", index=False)
