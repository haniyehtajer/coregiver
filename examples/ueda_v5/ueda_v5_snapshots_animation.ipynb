# %%
import os
import numpy as np
import pandas as pd
from coregiver import composition_tracker_v1 as ctv1

# %%
# ueda_v5 loop, uniform
n_runs = 60 # This variable is not used in the loop, you might want to remove it
cut_times = np.logspace(6, np.log10(299) + 6, 20)
for cut in cut_times:   
    for i in range(n_runs):
        collision_file = f"/Users/honeyeah/Codes/data/ueda_v5/ueda_v5_{i+1}/animation/filtered_collision_report_{int(cut/1e6)}Myrs.txt"
        comp_input_file = "/Users/honeyeah/Codes/coregiver/examples/ueda_v5/uniform_33.txt"

        ejec_file = f"/Users/honeyeah/Codes/data/ueda_v5/ueda_v5_{i+1}/ejections.txt"

        if os.path.exists(ejec_file):
            print('ejections file found.', i)
        else:
            ejec_file = "/Users/honeyeah/Codes/planetgarten/body_composition_tracker/test_input/ejections_empty.txt"
            print("ejections file not found, using an empty file.", i)

        comp_output_file = f"/Users/honeyeah/Codes/data/ueda_v5/ueda_v5_{i+1}/animation/uniform_33_{int(cut/1e6)}Myrs.txt"

        final_compositions = ctv1.track_composition(collision_file, comp_input_file, ejec_file)
        ctv1.write_output(final_compositions, comp_output_file)
        print(f"Processed ueda_v5 run {i+1}")
# Out:
# ejections file found. 0
# Processed ueda_v5 run 1
# ejections file not found, using an empty file. 1
# Processed ueda_v5 run 2
# ejections file found. 2
# Processed ueda_v5 run 3
# ejections file found. 3
# Processed ueda_v5 run 4
# ejections file found. 4
# Processed ueda_v5 run 5
# ejections file found. 5
# Processed ueda_v5 run 6
# ejections file found. 6
# Processed ueda_v5 run 7
# ejections file found. 7
# Processed ueda_v5 run 8
# ejections file found. 8
# Processed ueda_v5 run 9
# ejections file found. 9
# Processed ueda_v5 run 10
# ejections file found. 10
# Processed ueda_v5 run 11
# ejections file found. 11
# Processed ueda_v5 run 12
# ejections file found. 12
# Processed ueda_v5 run 13
# ejections file found. 13
# Processed ueda_v5 run 14
# ejections file found. 14
# Processed ueda_v5 run 15
# ejections file found. 15
# Processed ueda_v5 run 16
# ejections file found. 16
# Processed ueda_v5 run 17
# ejections file found. 17
# Processed ueda_v5 run 18
# ...

# %%
# ueda_v5 loop, step
n_runs = 60 # This variable is not used in the loop, you might want to remove it
cut_times = np.logspace(6, np.log10(299) + 6, 20)
for cut in cut_times:   
    for i in range(n_runs):
        collision_file = f"/Users/honeyeah/Codes/data/ueda_v5/ueda_v5_{i+1}/animation/filtered_collision_report_{int(cut/1e6)}Myrs.txt"
        comp_input_file = "/Users/honeyeah/Codes/coregiver/examples/ueda_v5/step_functions/ueda_v5_step_b0.7_p0.2.txt"

        ejec_file = f"/Users/honeyeah/Codes/data/ueda_v5/ueda_v5_{i+1}/ejections.txt"

        if os.path.exists(ejec_file):
            print('ejections file found.', i)
        else:
            ejec_file = "/Users/honeyeah/Codes/planetgarten/body_composition_tracker/test_input/ejections_empty.txt"
            print("ejections file not found, using an empty file.", i)

        comp_output_file = f"/Users/honeyeah/Codes/data/ueda_v5/ueda_v5_{i+1}/animation/step_b0.7_p0.20_{int(cut/1e6)}Myrs.txt"

        final_compositions = ctv1.track_composition(collision_file, comp_input_file, ejec_file)
        ctv1.write_output(final_compositions, comp_output_file)
        print(f"Processed ueda_v5 run {i+1}")
# Out:
# ejections file found. 0
# Processed ueda_v5 run 1
# ejections file not found, using an empty file. 1
# Processed ueda_v5 run 2
# ejections file found. 2
# Processed ueda_v5 run 3
# ejections file found. 3
# Processed ueda_v5 run 4
# ejections file found. 4
# Processed ueda_v5 run 5
# ejections file found. 5
# Processed ueda_v5 run 6
# ejections file found. 6
# Processed ueda_v5 run 7
# ejections file found. 7
# Processed ueda_v5 run 8
# ejections file found. 8
# Processed ueda_v5 run 9
# ejections file found. 9
# Processed ueda_v5 run 10
# ejections file found. 10
# Processed ueda_v5 run 11
# ejections file found. 11
# Processed ueda_v5 run 12
# ejections file found. 12
# Processed ueda_v5 run 13
# ejections file found. 13
# Processed ueda_v5 run 14
# ejections file found. 14
# Processed ueda_v5 run 15
# ejections file found. 15
# Processed ueda_v5 run 16
# ejections file found. 16
# Processed ueda_v5 run 17
# ejections file found. 17
# Processed ueda_v5 run 18
# ...
